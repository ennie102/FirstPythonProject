# %% [markdown]
# <a href="https://colab.research.google.com/github/ennie102/FirstPythonProject/blob/main/BeginnerProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("What is your name?")
print("Hello",name,"nice to meet you")
# Out:
# What is your name?Ennie
# Hello Ennie nice to meet you

# %%
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
sum=num1+num2
print("The sum of",num1,"and",num2,"is",sum)
# Out:
# Enter first number:3
# Enter second number:1
# The sum of 3 and 1 is 4

# %%
First_name=input("Enter your first name ")
last_name= input("Enter your last name ")
Age=int(input("Enter your age "))
full_name= First_name+" "+last_name
print("Your full name is", full_name,"and you are",Age,"years old")
# Out:
# Enter your first name Ennie
# Enter your last name Nokaneng
# Enter your age 22
# Your full name is Ennie Nokaneng you are 22 years old

# %%
num=int(input("Enter a number:"))
if num % 2 == 0:
  print(num,"is an even number.")
else:
  print(num,"is an odd number")
# Out:
# Enter a number:19
# 19 is an odd number

# %%
num=int(input("Enter a number:"))
if num % 2 == 0:
  print(num,"is an even number.")
else:
  print(num,"is an odd number")
# Out:
# Enter a number:2
# 2 is an even number.

# %%
num=int(input("Enter a number:"))
print("Countdown")
for i in range(num,0,-1):
  print(i)
print("Blast off!")
# Out:
# Enter a number:9
# Countdown
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# Blast off!

# %%
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
print(num1+num2)
# Out:
# Enter first number:2
# Enter second number:4
# 6

# %%
print("Im about to go home")
# Out:
# Im about to go home
